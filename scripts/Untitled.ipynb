# %%
import pandas as pd
from pathlib import Path

# %%
s = 'macd'
p = 'conservative'

df = pd.read_csv(Path(f"../MCdata/MCperformance/mc_performance_data_{s}_{p}.csv"),infer_datetime_format=True, parse_dates=True, index_col="index")

# %%
df
# Out:
#                 close  MACD_signal  Position  Entry/Exit Position  \
# index
# 2019-06-04  50.746000            0       650                  0.0
# 2019-06-05  51.063001            0       650                  0.0
# 2019-06-06  51.218999            1      1300                650.0
# 2019-06-07  51.706000            1      1300                  0.0
# 2019-06-10  51.771000            1      1300                  0.0
# ...               ...          ...       ...                  ...
# 2023-03-31  63.144998            1      1300                  0.0
# 2023-04-03  63.086001            1      1300                  0.0
# 2023-04-04  62.960001            1      1300                  0.0
# 2023-04-05  62.698999            1      1300                  0.0
# 2023-04-06  62.830000            1      1300                  0.0
#
#             Portfolio Holdings  Portfolio Cash  Portfolio Total  \
# index
# 2019-06-04        32984.899879   117238.050699    150222.950578
# 2019-06-05        33190.950565   117238.050699    150429.001265
# 2019-06-06        66584.699326    83945.701036    150530.400362
# 2019-06-07        67217.800303    83945.701036    151163.501339
# 2019-06-10        67302.299633    83945.701036    151248.000669
# ...                        ...             ...              ...
# 2023-03-31        82088.497124    88235.700448    170324.197571
# 2023-04-03        82011.801319    88235.700448    170247.501767
# 2023-04-04        81848.001165    88235.700448    170083.701613
# 2023-04-05        81508.698483    88235.700448    169744.398930
# 2023-04-06        81679.000397    88235.700448    169914.700844
#
#             Portfolio Daily Returns  Portfolio Cumulative Returns  \
# index
# 2019-06-04                 0.001486                      0.001486
# 2019-06-05                 0.001372                      0.002860
# 2019-06-06                 0.000674                      0.003536
# 2019-06-07                 0.004206                      0.007757
# 2019-06-10                 0.000559                      0.008320
# ...                             ...                           ...
# 2023-03-31                 0.004200                      0.135495
# 2023-04-03                -0.000450                      0.134983
# 2023-04-04                -0.000962                      0.133891
# 2023-04-05                -0.001995                      0.131629
# 2023-04-06                 0.001003                      0.132765
#
#             Base Daily Returns  Base Cumulative Returns
# index
# 2019-06-04            0.006805                 0.006805
# 2019-06-05            0.006247                 0.013094
# 2019-06-06            0.003055                 0.016190
# 2019-06-07            0.009508                 0.025852
# 2019-06-10            0.001257                 0.027141
# ...                        ...                      ...
# 2023-03-31            0.008754                 0.252802
# 2023-04-03           -0.000934                 0.251632
# 2023-04-04           -0.001997                 0.249132
# 2023-04-05           -0.004146                 0.243954
# 2023-04-06            0.002089                 0.246553
#
# [969 rows x 11 columns]
