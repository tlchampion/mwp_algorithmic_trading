# %%
# import modules
import panel as pn
pn.extension('tabulator')
import pandas as pd
import numpy as np
from panel.template import FastListTemplate
from pathlib import Path
from yahoo_fin.stock_info import get_data
import datetime
from matplotlib.figure import Figure
from matplotlib import cm
# %matplotlib inline
import hvplot.pandas
import holoviews as hv
from holoviews import opts


import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# import modules that help build tabs
import modules.helpers as helpers
import modules.HistoricalData as hst
import modules.MCTab as MCTab
import modules.intro as intro
import modules.profile as prf
import modules.algorithmic_functions as af


import pandas_ta as ta
import yfinance as yf

from sklearn.svm import SVC
from pandas.tseries.offsets import DateOffset
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, roc_auc_score, f1_score
import seaborn as sns

# set random seed for reproducible results
np.random.seed(8171)
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %% [markdown]
# ## Load Datasets and define portfolios being used# Compile Data

# %%
# af.create_train_test()

# %%
# load X_train_full and X_test_full
X_train_full_conservative = pd.read_csv(Path("./data/X_train_full_conservative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
X_test_full_conservative = pd.read_csv(Path("./data/X_test_full_conservative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

X_train_full_balanced = pd.read_csv(Path("./data/X_train_full_balanced.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
X_test_full_balanced = pd.read_csv(Path("./data/X_test_full_balanced.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

X_train_full_growth = pd.read_csv(Path("./data/X_train_full_growth.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
X_test_full_growth = pd.read_csv(Path("./data/X_test_full_growth.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

X_train_full_aggressive = pd.read_csv(Path("./data/X_train_full_aggressive.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
X_test_full_aggressive = pd.read_csv(Path("./data/X_test_full_aggressive.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

X_train_full_alternative = pd.read_csv(Path("./data/X_train_full_alternative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
X_test_full_alternative = pd.read_csv(Path("./data/X_test_full_alternative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)



#load y_train and y_test
y_train_conservative = pd.read_csv(Path("./data/y_train_conservative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
y_test_conservative = pd.read_csv(Path("./data/y_test_conservative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

y_train_balanced = pd.read_csv(Path("./data/y_train_balanced.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
y_test_balanced = pd.read_csv(Path("./data/y_test_balanced.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

y_train_growth = pd.read_csv(Path("./data/y_train_growth.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
y_test_growth = pd.read_csv(Path("./data/y_test_growth.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

y_train_aggressive = pd.read_csv(Path("./data/y_train_aggressive.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
y_test_aggressive = pd.read_csv(Path("./data/y_test_aggressive.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

y_train_alternative = pd.read_csv(Path("./data/y_train_alternative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
y_test_alternative = pd.read_csv(Path("./data/y_test_alternative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

datafiles_full = {'conservative': [X_train_full_conservative,
                              X_test_full_conservative, 
                              y_train_conservative, 
                              y_test_conservative],
            'balanced': [X_train_full_balanced,
                              X_test_full_balanced, 
                              y_train_balanced, 
                              y_test_balanced],
            'growth': [X_train_full_growth,
                              X_test_full_growth, 
                              y_train_growth, 
                              y_test_growth],
            'aggressive': [X_train_full_aggressive,
                              X_test_full_aggressive, 
                              y_train_aggressive, 
                              y_test_aggressive],
            'alternative': [X_train_full_alternative,
                              X_test_full_alternative, 
                              y_train_alternative, 
                              y_test_alternative]}


# load X_train_reduced and X_test_reduced
X_train_reduced_conservative = pd.read_csv(Path("./data/X_train_reduced_conservative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
X_test_reduced_conservative = pd.read_csv(Path("./data/X_test_reduced_conservative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

X_train_reduced_balanced = pd.read_csv(Path("./data/X_train_reduced_balanced.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
X_test_reduced_balanced = pd.read_csv(Path("./data/X_test_reduced_balanced.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

X_train_reduced_growth = pd.read_csv(Path("./data/X_train_reduced_growth.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
X_test_reduced_growth = pd.read_csv(Path("./data/X_test_reduced_growth.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

X_train_reduced_aggressive = pd.read_csv(Path("./data/X_train_reduced_aggressive.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
X_test_reduced_aggressive = pd.read_csv(Path("./data/X_test_reduced_aggressive.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

X_train_reduced_alternative = pd.read_csv(Path("./data/X_train_reduced_alternative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
X_test_reduced_alternative = pd.read_csv(Path("./data/X_test_reduced_alternative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)



#load y_train and y_test
y_train_conservative = pd.read_csv(Path("./data/y_train_conservative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
y_test_conservative = pd.read_csv(Path("./data/y_test_conservative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

y_train_balanced = pd.read_csv(Path("./data/y_train_balanced.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
y_test_balanced = pd.read_csv(Path("./data/y_test_balanced.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

y_train_growth = pd.read_csv(Path("./data/y_train_growth.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
y_test_growth = pd.read_csv(Path("./data/y_test_growth.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

y_train_aggressive = pd.read_csv(Path("./data/y_train_aggressive.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
y_test_aggressive = pd.read_csv(Path("./data/y_test_aggressive.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

y_train_alternative = pd.read_csv(Path("./data/y_train_alternative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
y_test_alternative = pd.read_csv(Path("./data/y_test_alternative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

datafiles_reduced = {'conservative': [X_train_reduced_conservative,
                              X_test_reduced_conservative, 
                              y_train_conservative, 
                              y_test_conservative],
            'balanced': [X_train_reduced_balanced,
                              X_test_reduced_balanced, 
                              y_train_balanced, 
                              y_test_balanced],
            'growth': [X_train_reduced_growth,
                              X_test_reduced_growth, 
                              y_train_growth, 
                              y_test_growth],
            'aggressive': [X_train_reduced_aggressive,
                              X_test_reduced_aggressive, 
                              y_train_aggressive, 
                              y_test_aggressive],
            'alternative': [X_train_reduced_alternative,
                              X_test_reduced_alternative, 
                              y_train_alternative, 
                              y_test_alternative]}

portfolios = ['conservative', 'balanced', 'growth', 'aggressive','alternative']

# %% [markdown]
# ## Define model parameters for each model to be trained

# %% [markdown]
# ### initialize standard scaler

# %%
scaler = StandardScaler()

# %% [markdown]
# ### Initialize SVM models for training and subsequent evaluation/comparison

# %%
model1 = SVC(random_state=42, max_iter=1000, kernel='linear', C=0.5, probability=True)
model2 = SVC(random_state=42, max_iter=1000, kernel='linear',C=1, probability=True)
model3 = SVC(random_state=42, max_iter=1000, kernel='linear',C=10, probability=True)
model4 = SVC(random_state=42, max_iter=1000, kernel='rbf',C=0.5, probability=True)
model5 = SVC(random_state=42, max_iter=1000, kernel='rbf',C=1, probability=True)
model6 = SVC(random_state=42, max_iter=1000, kernel='rbf',C=10, probability=True)
model7 = SVC(random_state=42, max_iter=1000, kernel='sigmoid',C=0.5, probability=True)
model8 = SVC(random_state=42, max_iter=1000, kernel='sigmoid',C=1, probability=True)
model9 = SVC(random_state=42, max_iter=1000, kernel='sigmoid',C=10, probability=True)

# %% [markdown]
# ## Setup model pipeline, consisting of data scaling and the model training/fitting
#
# ### Loop through defined models, fitting and evaluating each model for both the full and reduced features datasets. Save evaluation results to a table for later comparisons

# %%
# create list of defined models that can be looped through for fit/evaluation
models = [model1, model2, model3, model4, model5, model6, model7, model8, model9]

# %%
datafiles = datafiles_full
df_full_results = pd.DataFrame()
for portfolio in portfolios:
    X_train = datafiles[portfolio][0]
    X_test = datafiles[portfolio][1]
    y_train = datafiles[portfolio][2]
    y_test = datafiles[portfolio][3]
    i=1
    df_results = pd.DataFrame()
    for model in models:
        pipeline = Pipeline([('scaler', scaler), ('model', model)])
        pipeline.fit(X_train, y_train)
        preds = pipeline.predict(X_test)
        proba = pipeline.predict_proba(X_test)
        roc = roc_auc_score(y_test,proba[:,1])
        f1 = f1_score(y_test, preds)
        df = pd.DataFrame()
        df.loc['f1_score',f"model{i}"] = f1
        df.loc['roc_auc_score',f"model{i}"] = roc
        df_results = pd.concat([df_results, df], axis=1)
        i += 1
    df_results['type'] = portfolio
    df_full_results = pd.concat([df_full_results, df_results])
    
df_full_results.set_index('type', append=True, inplace=True)
df_full_results = df_full_results.reorder_levels(['type', 0])

# %%
datafiles = datafiles_reduced

df_reduced_results = pd.DataFrame()
for portfolio in portfolios:
    X_train = datafiles[portfolio][0]
    X_test = datafiles[portfolio][1]
    y_train = datafiles[portfolio][2]
    y_test = datafiles[portfolio][3]
    i=1
    df_results = pd.DataFrame()
    for model in models:
        pipeline = Pipeline([('scaler', scaler), ('model', model)])
        pipeline.fit(X_train, y_train)
        preds = pipeline.predict(X_test)
        proba = pipeline.predict_proba(X_test)
        roc = roc_auc_score(y_test,proba[:,1])
        f1 = f1_score(y_test, preds)
        df = pd.DataFrame()
        df.loc['f1_score',f"model{i}"] = f1
        df.loc['roc_auc_score',f"model{i}"] = roc
        df_results = pd.concat([df_results, df], axis=1)
        i += 1
    df_results['type'] = portfolio
    df_reduced_results = pd.concat([df_reduced_results, df_results])
    
df_reduced_results.set_index('type', append=True, inplace=True)
df_reduced_results = df_reduced_results.reorder_levels(['type', 0])

# %% [markdown]
# ### Combine evaluation metrics into one table for review and selection of best model for comparison to other model types

# %%
df_reduced_results['type'] = 'SVM Classifier - Reduced'
df_full_results['type'] = 'SVM Classifier - Full'


df_reduced_results.set_index('type', append=True,inplace=True)
df_full_results.set_index('type', append=True,inplace=True)

df_reduced_results = df_reduced_results.unstack(level=2)

df_reduced_results = df_reduced_results.reorder_levels([1,0], axis=1)


df_full_results = df_full_results.unstack(level=2)

df_full_results = df_full_results.reorder_levels([1,0], axis=1)

df_svm_results = pd.concat([df_reduced_results, df_full_results], axis=1)

cm = sns.light_palette("blue", as_cmap=True)
pd.set_option('display.max_columns', None)



df_svm_results.style.highlight_max(color='lightblue', axis = 1).set_caption("Metrics Comparison for All Models")
# Out:
# <style type="text/css">
# #T_7582a_row0_col0, #T_7582a_row0_col1, #T_7582a_row0_col2, #T_7582a_row0_col3, #T_7582a_row0_col4, #T_7582a_row0_col9, #T_7582a_row0_col10, #T_7582a_row0_col11, #T_7582a_row0_col12, #T_7582a_row0_col13, #T_7582a_row1_col6, #T_7582a_row2_col0, #T_7582a_row2_col1, #T_7582a_row2_col2, #T_7582a_row2_col3, #T_7582a_row2_col4, #T_7582a_row2_col6, #T_7582a_row2_col7, #T_7582a_row2_col8, #T_7582a_row2_col9, #T_7582a_row2_col10, #T_7582a_row2_col12, #T_7582a_row3_col2, #T_7582a_row4_col17, #T_7582a_row5_col17, #T_7582a_row6_col0, #T_7582a_row6_col1, #T_7582a_row6_col2, #T_7582a_row6_col3, #T_7582a_row6_col9, #T_7582a_row6_col10, #T_7582a_row7_col14, #T_7582a_row8_col0, #T_7582a_row8_col1, #T_7582a_row8_col2, #T_7582a_row8_col3, #T_7582a_row8_col4, #T_7582a_row8_col9, #T_7582a_row8_col10, #T_7582a_row8_col12, #T_7582a_row8_col13, #T_7582a_row9_col7 {
#   background-color: lightblue;
# }
# </style>
# <table id="T_7582a">
#   <caption>Metrics Comparison for All Models</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >type</th>
#       <th id="T_7582a_level0_col0" class="col_heading level0 col0" colspan="9">SVM Classifier - Reduced</th>
#       <th id="T_7582a_level0_col9" class="col_heading level0 col9" colspan="9">SVM Classifier - Full</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_7582a_level1_col0" class="col_heading level1 col0" >model1</th>
#       <th id="T_7582a_level1_col1" class="col_heading level1 col1" >model2</th>
#       <th id="T_7582a_level1_col2" class="col_heading level1 col2" >model3</th>
#       <th id="T_7582a_level1_col3" class="col_heading level1 col3" >model4</th>
#       <th id="T_7582a_level1_col4" class="col_heading level1 col4" >model5</th>
#       <th id="T_7582a_level1_col5" class="col_heading level1 col5" >model6</th>
#       <th id="T_7582a_level1_col6" class="col_heading level1 col6" >model7</th>
#       <th id="T_7582a_level1_col7" class="col_heading level1 col7" >model8</th>
#       <th id="T_7582a_level1_col8" class="col_heading level1 col8" >model9</th>
#       <th id="T_7582a_level1_col9" class="col_heading level1 col9" >model1</th>
#       <th id="T_7582a_level1_col10" class="col_heading level1 col10" >model2</th>
#       <th id="T_7582a_level1_col11" class="col_heading level1 col11" >model3</th>
#       <th id="T_7582a_level1_col12" class="col_heading level1 col12" >model4</th>
#       <th id="T_7582a_level1_col13" class="col_heading level1 col13" >model5</th>
#       <th id="T_7582a_level1_col14" class="col_heading level1 col14" >model6</th>
#       <th id="T_7582a_level1_col15" class="col_heading level1 col15" >model7</th>
#       <th id="T_7582a_level1_col16" class="col_heading level1 col16" >model8</th>
#       <th id="T_7582a_level1_col17" class="col_heading level1 col17" >model9</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >type</th>
#       <th class="index_name level1" >&nbsp;</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7582a_level0_row0" class="row_heading level0 row0" rowspan="2">aggressive</th>
#       <th id="T_7582a_level1_row0" class="row_heading level1 row0" >f1_score</th>
#       <td id="T_7582a_row0_col0" class="data row0 col0" >0.696104</td>
#       <td id="T_7582a_row0_col1" class="data row0 col1" >0.696104</td>
#       <td id="T_7582a_row0_col2" class="data row0 col2" >0.696104</td>
#       <td id="T_7582a_row0_col3" class="data row0 col3" >0.696104</td>
#       <td id="T_7582a_row0_col4" class="data row0 col4" >0.696104</td>
#       <td id="T_7582a_row0_col5" class="data row0 col5" >0.481633</td>
#       <td id="T_7582a_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_7582a_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_7582a_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_7582a_row0_col9" class="data row0 col9" >0.696104</td>
#       <td id="T_7582a_row0_col10" class="data row0 col10" >0.696104</td>
#       <td id="T_7582a_row0_col11" class="data row0 col11" >0.696104</td>
#       <td id="T_7582a_row0_col12" class="data row0 col12" >0.696104</td>
#       <td id="T_7582a_row0_col13" class="data row0 col13" >0.696104</td>
#       <td id="T_7582a_row0_col14" class="data row0 col14" >0.181818</td>
#       <td id="T_7582a_row0_col15" class="data row0 col15" >0.403670</td>
#       <td id="T_7582a_row0_col16" class="data row0 col16" >0.375587</td>
#       <td id="T_7582a_row0_col17" class="data row0 col17" >0.409091</td>
#     </tr>
#     <tr>
#       <th id="T_7582a_level1_row1" class="row_heading level1 row1" >roc_auc_score</th>
#       <td id="T_7582a_row1_col0" class="data row1 col0" >0.513267</td>
#       <td id="T_7582a_row1_col1" class="data row1 col1" >0.512438</td>
#       <td id="T_7582a_row1_col2" class="data row1 col2" >0.493175</td>
#       <td id="T_7582a_row1_col3" class="data row1 col3" >0.532721</td>
#       <td id="T_7582a_row1_col4" class="data row1 col4" >0.507399</td>
#       <td id="T_7582a_row1_col5" class="data row1 col5" >0.486637</td>
#       <td id="T_7582a_row1_col6" class="data row1 col6" >0.552622</td>
#       <td id="T_7582a_row1_col7" class="data row1 col7" >0.538780</td>
#       <td id="T_7582a_row1_col8" class="data row1 col8" >0.464983</td>
#       <td id="T_7582a_row1_col9" class="data row1 col9" >0.480291</td>
#       <td id="T_7582a_row1_col10" class="data row1 col10" >0.545350</td>
#       <td id="T_7582a_row1_col11" class="data row1 col11" >0.462878</td>
#       <td id="T_7582a_row1_col12" class="data row1 col12" >0.481375</td>
#       <td id="T_7582a_row1_col13" class="data row1 col13" >0.496364</td>
#       <td id="T_7582a_row1_col14" class="data row1 col14" >0.537377</td>
#       <td id="T_7582a_row1_col15" class="data row1 col15" >0.529085</td>
#       <td id="T_7582a_row1_col16" class="data row1 col16" >0.526088</td>
#       <td id="T_7582a_row1_col17" class="data row1 col17" >0.475061</td>
#     </tr>
#     <tr>
#       <th id="T_7582a_level0_row2" class="row_heading level0 row2" rowspan="2">alternative</th>
#       <th id="T_7582a_level1_row2" class="row_heading level1 row2" >f1_score</th>
#       <td id="T_7582a_row2_col0" class="data row2 col0" >0.696104</td>
#       <td id="T_7582a_row2_col1" class="data row2 col1" >0.696104</td>
#       <td id="T_7582a_row2_col2" class="data row2 col2" >0.696104</td>
#       <td id="T_7582a_row2_col3" class="data row2 col3" >0.696104</td>
#       <td id="T_7582a_row2_col4" class="data row2 col4" >0.696104</td>
#       <td id="T_7582a_row2_col5" class="data row2 col5" >0.536398</td>
#       <td id="T_7582a_row2_col6" class="data row2 col6" >0.696104</td>
#       <td id="T_7582a_row2_col7" class="data row2 col7" >0.696104</td>
#       <td id="T_7582a_row2_col8" class="data row2 col8" >0.696104</td>
#       <td id="T_7582a_row2_col9" class="data row2 col9" >0.696104</td>
#       <td id="T_7582a_row2_col10" class="data row2 col10" >0.696104</td>
#       <td id="T_7582a_row2_col11" class="data row2 col11" >0.686016</td>
#       <td id="T_7582a_row2_col12" class="data row2 col12" >0.696104</td>
#       <td id="T_7582a_row2_col13" class="data row2 col13" >0.687664</td>
#       <td id="T_7582a_row2_col14" class="data row2 col14" >0.084507</td>
#       <td id="T_7582a_row2_col15" class="data row2 col15" >0.401826<

# %%
df_svm_results.style.background_gradient(axis=1)
# Out:
# <style type="text/css">
# #T_082d6_row0_col0, #T_082d6_row0_col1, #T_082d6_row0_col2, #T_082d6_row0_col3, #T_082d6_row0_col4, #T_082d6_row0_col9, #T_082d6_row0_col10, #T_082d6_row0_col11, #T_082d6_row0_col12, #T_082d6_row0_col13, #T_082d6_row1_col6, #T_082d6_row2_col0, #T_082d6_row2_col1, #T_082d6_row2_col2, #T_082d6_row2_col3, #T_082d6_row2_col4, #T_082d6_row2_col6, #T_082d6_row2_col7, #T_082d6_row2_col8, #T_082d6_row2_col9, #T_082d6_row2_col10, #T_082d6_row2_col12, #T_082d6_row3_col2, #T_082d6_row4_col0, #T_082d6_row4_col1, #T_082d6_row4_col2, #T_082d6_row4_col3, #T_082d6_row4_col4, #T_082d6_row4_col9, #T_082d6_row4_col10, #T_082d6_row4_col11, #T_082d6_row4_col12, #T_082d6_row4_col13, #T_082d6_row4_col16, #T_082d6_row4_col17, #T_082d6_row5_col17, #T_082d6_row6_col0, #T_082d6_row6_col1, #T_082d6_row6_col2, #T_082d6_row6_col3, #T_082d6_row6_col9, #T_082d6_row6_col10, #T_082d6_row7_col14, #T_082d6_row8_col0, #T_082d6_row8_col1, #T_082d6_row8_col2, #T_082d6_row8_col3, #T_082d6_row8_col4, #T_082d6_row8_col9, #T_082d6_row8_col10, #T_082d6_row8_col12, #T_082d6_row8_col13, #T_082d6_row9_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_082d6_row0_col5, #T_082d6_row7_col8 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_082d6_row0_col6, #T_082d6_row0_col7, #T_082d6_row0_col8, #T_082d6_row1_col11, #T_082d6_row2_col14, #T_082d6_row3_col9, #T_082d6_row4_col6, #T_082d6_row4_col7, #T_082d6_row4_col8, #T_082d6_row5_col8, #T_082d6_row6_col8, #T_082d6_row7_col13, #T_082d6_row8_col6, #T_082d6_row8_col7, #T_082d6_row8_col8, #T_082d6_row9_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_082d6_row0_col14 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_082d6_row0_col15 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_082d6_row0_col16, #T_082d6_row5_col10 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_082d6_row0_col17 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_082d6_row1_col0, #T_082d6_row6_col4 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_082d6_row1_col1 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_082d6_row1_col2 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_082d6_row1_col3 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_082d6_row1_col4 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_082d6_row1_col5 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_082d6_row1_col7 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_082d6_row1_col8 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_082d6_row1_col9 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_082d6_row1_col10 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# #T_082d6_row1_col12 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_082d6_row1_col13, #T_082d6_row9_col11 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_082d6_row1_col14 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_082d6_row1_col15 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_082d6_row1_col16 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_082d6_row1_col17 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_082d6_row2_col5 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_082d6_row2_col11, #T_082d6_row3_col11 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_082d6_row2_col13, #T_082d6_row6_col12 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_082d6_row2_col15 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_082d6_row2_col16 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_082d6_row2_col17 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_082d6_row3_col0 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_082d6_row3_col1 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_082d6_row3_col3 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_082d6_row3_col4 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_082d6_row3_col5 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_082d6_row3_col6, #T_082d6_row3_col7 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_082d6_row3_col8 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_082d6_row3_col10 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_082d6_row3_col12 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_082d6_row3_col13 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_082d6_row3_col14, #T_082d6_row9_col8 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_082d6_row3_col15 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_082d6_row3_col16 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_082d6_row3_col17 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_082d6_row4_col5 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_082d6_row4_col14 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_082d6_row4_col15 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_082d6_row5_col0 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_082d6_row5_col1, #T_082d6_row7_col9 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_082d6_row5_col2 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_082d6_row5_col3 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_082d6_row5_col4 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_082d6_row5_col5 {
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# #T_082d6_row5_col6, #T_082d6_row6_col6 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_082d6_row5_col7 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_082d6_row5_col9 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_082d6_row5_col11 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_082d6_row5_col12, #T_082d6_row5_col13 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_082d6_row5_col14, #T_082d6_row9_col15 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_082d6_row5_col15 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_082d6_row5_col16, #T_082d6_row9_col6 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_082d6_row6_col5 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_082d6_row6_col7 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_082d6_row6_col11 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_082d6_row6_col13, #T_082d6_row6_col16, #T_082d6_row6_col17 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_082d6_row6_col14 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_082d6_row6_col15 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_082d6_row7_col0, #T_082d6_row7_col10 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_082d6_row7_col1 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_082d6_row7_col2 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_082d6_row7_col3 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_082d6_row7_col4 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_082d6_row7_col5 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_082d6_row7_col6 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_082d6_row7_col7 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_082d6_row7_col11 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_082d6_row7_col12 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_082d6_row7_col15 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_082d6_row7_col16, #T_082d6_row7_col17 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_082d6_row8_col5 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_082d6_row8_col11 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_082d6_row8_col14 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_082d6_row8_col15 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_082d6_row8_col16, #T_082d6_row8_col17 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_082d6_row9_col0 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_082d6_row9_col1 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_082d6_row9_col2 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_082d6_row9_col3, #T_082d6_row9_col4 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_082d6_row9_col9 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_082d6_row9_col10 {

# %% [markdown]
# ### save evalution metrics of selected model for comparison with metrics from other model types

# %%
best = df_svm_results['SVM Classifier - Reduced'][['model3']]

best.reset_index(inplace=True)

best.to_csv(Path("./model_metrics/svm.csv"), index=False)
