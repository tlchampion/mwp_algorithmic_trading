# %%
# import modules
import panel as pn
pn.extension('tabulator')
import pandas as pd
import numpy as np
from panel.template import FastListTemplate
from pathlib import Path
from yahoo_fin.stock_info import get_data
import datetime
from matplotlib.figure import Figure
from matplotlib import cm
# %matplotlib inline
import hvplot.pandas
import holoviews as hv
from holoviews import opts


import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# import modules that help build tabs
import modules.helpers as helpers
import modules.HistoricalData as hst
import modules.MCTab as MCTab
import modules.intro as intro
import modules.profile as prf
import modules.algorithmic_functions as af


import pandas_ta as ta
import yfinance as yf

from sklearn.ensemble import RandomForestClassifier
from pandas.tseries.offsets import DateOffset
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

import seaborn as sns
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %% [markdown]
# # Compile Data

# %% [markdown]
# ## * If necessary/desired, use 'build_portfolio_signal_ml_df' to pull machine learning data to create/refresht he test/train datasets
#
# ## * Load the test/train datasets

# %%
# signals_df, ml_df = af.build_portfolio_signal_ml_df('conservative',2017,12,31)

# af.create_train_test(ml_df)

# %%
# load X_train_full and X_test_full
X_train_full_conservative = pd.read_csv(Path("./data/X_train_full_conservative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
X_test_full_conservative = pd.read_csv(Path("./data/X_test_full_conservative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

X_train_full_balanced = pd.read_csv(Path("./data/X_train_full_balanced.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
X_test_full_balanced = pd.read_csv(Path("./data/X_test_full_balanced.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

X_train_full_growth = pd.read_csv(Path("./data/X_train_full_growth.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
X_test_full_growth = pd.read_csv(Path("./data/X_test_full_growth.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

X_train_full_aggressive = pd.read_csv(Path("./data/X_train_full_aggressive.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
X_test_full_aggressive = pd.read_csv(Path("./data/X_test_full_aggressive.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

X_train_full_alternative = pd.read_csv(Path("./data/X_train_full_alternative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
X_test_full_alternative = pd.read_csv(Path("./data/X_test_full_alternative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)



#load y_train and y_test
y_train_conservative = pd.read_csv(Path("./data/y_train_conservative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
y_test_conservative = pd.read_csv(Path("./data/y_test_conservative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

y_train_balanced = pd.read_csv(Path("./data/y_train_balanced.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
y_test_balanced = pd.read_csv(Path("./data/y_test_balanced.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

y_train_growth = pd.read_csv(Path("./data/y_train_growth.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
y_test_growth = pd.read_csv(Path("./data/y_test_growth.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

y_train_aggressive = pd.read_csv(Path("./data/y_train_aggressive.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
y_test_aggressive = pd.read_csv(Path("./data/y_test_aggressive.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

y_train_alternative = pd.read_csv(Path("./data/y_train_alternative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
y_test_alternative = pd.read_csv(Path("./data/y_test_alternative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

datafiles = {'conservative': [X_train_full_conservative,
                              X_test_full_conservative, 
                              y_train_conservative, 
                              y_test_conservative],
            'balanced': [X_train_full_balanced,
                              X_test_full_balanced, 
                              y_train_balanced, 
                              y_test_balanced],
            'growth': [X_train_full_growth,
                              X_test_full_growth, 
                              y_train_growth, 
                              y_test_growth],
            'aggressive': [X_train_full_aggressive,
                              X_test_full_aggressive, 
                              y_train_aggressive, 
                              y_test_aggressive],
            'alternative': [X_train_full_alternative,
                              X_test_full_alternative, 
                              y_train_alternative, 
                              y_test_alternative]}

portfolios = ['conservative', 'balanced', 'growth', 'aggressive','alternative']

# %% [markdown]
# ## Create model

# %%
# initialize standard scaler

scaler = StandardScaler()

# %%
# Initialize bagging classifier models for training and subsequent evaluation/comparison
model1 = RandomForestClassifier(n_estimators=100, max_depth=10, min_samples_split=5, min_samples_leaf=1, max_features='sqrt', bootstrap=True, criterion='gini', min_impurity_decrease=0.0, class_weight=None, oob_score=False)
model2 = RandomForestClassifier(n_estimators=200, max_depth=20, min_samples_split=10, min_samples_leaf=5, max_features='log2', bootstrap=True, criterion='entropy', min_impurity_decrease=0.001, class_weight='balanced_subsample', oob_score=True)
model3 = RandomForestClassifier(n_estimators=500, max_depth=30, min_samples_split=20, min_samples_leaf=10, max_features=0.5, bootstrap=True, criterion='gini', min_impurity_decrease=0.005, class_weight={0: 1, 1: 3}, oob_score=True)
model4 = RandomForestClassifier(n_estimators=1000, max_depth=40, min_samples_split=50, min_samples_leaf=20, max_features=None, bootstrap=True, criterion='entropy', min_impurity_decrease=0.01, class_weight={0: 1, 1: 5}, oob_score=True)
model5 = RandomForestClassifier(n_estimators=200, max_depth=20, min_samples_split=10, min_samples_leaf=5, max_features=0.7, bootstrap=True, criterion='gini', min_impurity_decrease=0.0, class_weight=None, oob_score=False)
model6 = RandomForestClassifier(n_estimators=500, max_depth=30, min_samples_split=20, min_samples_leaf=10, max_features=0.3, bootstrap=True, criterion='entropy', min_impurity_decrease=0.0, class_weight='balanced', oob_score=True)
model7 = RandomForestClassifier(n_estimators=1000, max_depth=40, min_samples_split=50, min_samples_leaf=20, max_features='sqrt', bootstrap=True, criterion='gini', min_impurity_decrease=0.0, class_weight={0: 1, 1: 10}, oob_score=True)
model8 = RandomForestClassifier(n_estimators=2000, max_depth=50, min_samples_split=100, min_samples_leaf=50, max_features='log2', bootstrap=True, criterion='entropy', min_impurity_decrease=0.0, class_weight=None, oob_score=False)
model9 = RandomForestClassifier(n_estimators=1000, max_depth=30, min_samples_split=20, min_samples_leaf=10, max_features=None, bootstrap=True, criterion='gini', min_impurity_decrease=0.005, class_weight='balanced', oob_score=True)
model10 = RandomForestClassifier(n_estimators=500, max_depth=20, min_samples_split=10, min_samples_leaf=5, max_features=0.7, bootstrap=True, criterion='entropy', min_impurity_decrease=0.001, class_weight={0: 1, 1: 5}, oob_score=True)
model11 = RandomForestClassifier(n_estimators=1000, max_depth=30, min_samples_split=10, min_samples_leaf=5, max_features=0.5, bootstrap=True, criterion='entropy', min_impurity_decrease=0.001, class_weight='balanced', oob_score=True)

# %%
portfolios = ['conservative', 'balanced', 'growth', 'aggressive', 'alternative']

# %% [markdown]
# ## fitting and evaluating models
# We use a loop to train/test each model with each portfolio class, then display metrics for all runs

# %%
# will fit/evaluate multiple models using a series of for-loops. Models will be built using all indicators at once, just SMA inidcators, just MACD indicators, and just Bollinger Band indicators
# create list of defined models that can be looped through for fit/evaluation

models = [model1, model2, model3, model4, model5, model6, model7, model8, model9, model10, model11]

# %%
df_full_results = pd.DataFrame()
for portfolio in portfolios:
    X_train = datafiles[portfolio][0]
    X_test = datafiles[portfolio][1]
    y_train = datafiles[portfolio][2]
    y_test = datafiles[portfolio][3]
    i=1
    df_results = pd.DataFrame()
    for model in models:
        pipeline = Pipeline([('scaler', scaler), ('model', model)])
        pipeline.fit(X_train, y_train)
        preds = pipeline.predict(X_test)
        report = classification_report(y_test, preds, output_dict=True)
        df = pd.DataFrame.from_dict(report['weighted avg'], orient='index', columns=[f'model{i}'])
        df.loc['accuracy',f'model{i}'] = report['accuracy']
        df_results = pd.concat([df_results, df], axis=1)
        df_results.drop('support', inplace=True)
        i += 1
    df_results['type'] = portfolio
    df_full_results = pd.concat([df_full_results, df_results])
    
df_full_results.set_index('type', append=True, inplace=True)
df_full_results = df_full_results.reorder_levels(['type', 0])

# %%
cm = sns.light_palette("blue", as_cmap=True)
df_full_results.style.background_gradient(cmap=cm, axis=1).set_caption("Metrics for Full Train/Test Datasets")
# Out:
# <style type="text/css">
# #T_ab127_row0_col0, #T_ab127_row12_col5 {
#   background-color: #0303ff;
#   color: #f1f1f1;
# }
# #T_ab127_row0_col1, #T_ab127_row8_col7, #T_ab127_row13_col0, #T_ab127_row15_col0 {
#   background-color: #2929fd;
#   color: #f1f1f1;
# }
# #T_ab127_row0_col2, #T_ab127_row0_col3, #T_ab127_row0_col6, #T_ab127_row1_col1, #T_ab127_row2_col2, #T_ab127_row2_col3, #T_ab127_row2_col6, #T_ab127_row3_col1, #T_ab127_row4_col2, #T_ab127_row4_col3, #T_ab127_row4_col6, #T_ab127_row5_col2, #T_ab127_row5_col3, #T_ab127_row5_col6, #T_ab127_row6_col2, #T_ab127_row6_col3, #T_ab127_row6_col6, #T_ab127_row7_col2, #T_ab127_row7_col3, #T_ab127_row7_col6, #T_ab127_row8_col3, #T_ab127_row8_col6, #T_ab127_row9_col2, #T_ab127_row10_col3, #T_ab127_row10_col6, #T_ab127_row11_col2, #T_ab127_row12_col2, #T_ab127_row12_col3, #T_ab127_row12_col6, #T_ab127_row13_col2, #T_ab127_row13_col3, #T_ab127_row13_col6, #T_ab127_row14_col2, #T_ab127_row14_col3, #T_ab127_row14_col6, #T_ab127_row15_col2, #T_ab127_row15_col3, #T_ab127_row15_col6, #T_ab127_row16_col2, #T_ab127_row16_col3, #T_ab127_row16_col6, #T_ab127_row17_col2, #T_ab127_row17_col3, #T_ab127_row17_col6, #T_ab127_row18_col2, #T_ab127_row18_col3, #T_ab127_row18_col6, #T_ab127_row19_col2, #T_ab127_row19_col3, #T_ab127_row19_col6 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_ab127_row0_col4, #T_ab127_row2_col4, #T_ab127_row10_col1, #T_ab127_row16_col9, #T_ab127_row17_col0, #T_ab127_row19_col0 {
#   background-color: #1010fe;
#   color: #f1f1f1;
# }
# #T_ab127_row0_col5, #T_ab127_row2_col5 {
#   background-color: #2323fd;
#   color: #f1f1f1;
# }
# #T_ab127_row0_col7, #T_ab127_row17_col8, #T_ab127_row19_col8 {
#   background-color: #6060fa;
#   color: #f1f1f1;
# }
# #T_ab127_row0_col8 {
#   background-color: #2626fd;
#   color: #f1f1f1;
# }
# #T_ab127_row0_col9, #T_ab127_row1_col0, #T_ab127_row2_col0, #T_ab127_row3_col0, #T_ab127_row4_col7, #T_ab127_row5_col0, #T_ab127_row5_col1, #T_ab127_row6_col1, #T_ab127_row7_col0, #T_ab127_row7_col1, #T_ab127_row8_col8, #T_ab127_row8_col10, #T_ab127_row9_col10, #T_ab127_row10_col10, #T_ab127_row11_col10, #T_ab127_row12_col8, #T_ab127_row13_col1, #T_ab127_row13_col4, #T_ab127_row14_col4, #T_ab127_row15_col1, #T_ab127_row15_col4, #T_ab127_row16_col1, #T_ab127_row17_col1, #T_ab127_row18_col0, #T_ab127_row19_col1 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_ab127_row0_col10, #T_ab127_row14_col8, #T_ab127_row18_col9 {
#   background-color: #2222fd;
#   color: #f1f1f1;
# }
# #T_ab127_row1_col2, #T_ab127_row1_col3, #T_ab127_row1_col6, #T_ab127_row3_col2, #T_ab127_row3_col3, #T_ab127_row3_col6 {
#   background-color: #a0a0f7;
#   color: #f1f1f1;
# }
# #T_ab127_row1_col4, #T_ab127_row1_col9, #T_ab127_row3_col4, #T_ab127_row3_col9, #T_ab127_row17_col4, #T_ab127_row19_col4 {
#   background-color: #5050fb;
#   color: #f1f1f1;
# }
# #T_ab127_row1_col5, #T_ab127_row1_col8, #T_ab127_row1_col10, #T_ab127_row3_col5, #T_ab127_row3_col8, #T_ab127_row3_col10 {
#   background-color: #bcbcf5;
#   color: #000000;
# }
# #T_ab127_row1_col7, #T_ab127_row3_col7 {
#   background-color: #d6d6f4;
#   color: #000000;
# }
# #T_ab127_row2_col1, #T_ab127_row17_col5, #T_ab127_row19_col5 {
#   background-color: #3030fd;
#   color: #f1f1f1;
# }
# #T_ab127_row2_col7 {
#   background-color: #e2e2f3;
#   color: #000000;
# }
# #T_ab127_row2_col8, #T_ab127_row2_col10, #T_ab127_row14_col9 {
#   background-color: #2424fd;
#   color: #f1f1f1;
# }
# #T_ab127_row2_col9 {
#   background-color: #5f5ffa;
#   color: #f1f1f1;
# }
# #T_ab127_row4_col0, #T_ab127_row8_col2 {
#   background-color: #5656fb;
#   color: #f1f1f1;
# }
# #T_ab127_row4_col1 {
#   background-color: #5b5bfa;
#   color: #f1f1f1;
# }
# #T_ab127_row4_col4 {
#   background-color: #6a6afa;
#   color: #f1f1f1;
# }
# #T_ab127_row4_col5, #T_ab127_row17_col10, #T_ab127_row19_col10 {
#   background-color: #7070f9;
#   color: #f1f1f1;
# }
# #T_ab127_row4_col8 {
#   background-color: #7474f9;
#   color: #f1f1f1;
# }
# #T_ab127_row4_col9 {
#   background-color: #3a3afc;
#   color: #f1f1f1;
# }
# #T_ab127_row4_col10 {
#   background-color: #7171f9;
#   color: #f1f1f1;
# }
# #T_ab127_row5_col4, #T_ab127_row7_col4 {
#   background-color: #8383f8;
#   color: #f1f1f1;
# }
# #T_ab127_row5_col5, #T_ab127_row5_col8, #T_ab127_row5_col9, #T_ab127_row7_col5, #T_ab127_row7_col8, #T_ab127_row7_col9 {
#   background-color: #9999f7;
#   color: #f1f1f1;
# }
# #T_ab127_row5_col7, #T_ab127_row7_col7 {
#   background-color: #dbdbf4;
#   color: #000000;
# }
# #T_ab127_row5_col10, #T_ab127_row7_col10 {
#   background-color: #afaff6;
#   color: #000000;
# }
# #T_ab127_row6_col0, #T_ab127_row8_col1, #T_ab127_row18_col4 {
#   background-color: #0f0ffe;
#   color: #f1f1f1;
# }
# #T_ab127_row6_col4 {
#   background-color: #3535fc;
#   color: #f1f1f1;
# }
# #T_ab127_row6_col5 {
#   background-color: #1a1afe;
#   color: #f1f1f1;
# }
# #T_ab127_row6_col7 {
#   background-color: #e4e4f3;
#   color: #000000;
# }
# #T_ab127_row6_col8, #T_ab127_row12_col0, #T_ab127_row14_col0, #T_ab127_row18_col1 {
#   background-color: #0909ff;
#   color: #f1f1f1;
# }
# #T_ab127_row6_col9 {
#   background-color: #adadf6;
#   color: #000000;
# }
# #T_ab127_row6_col10 {
#   background-color: #2e2efd;
#   color: #f1f1f1;
# }
# #T_ab127_row8_col0, #T_ab127_row13_col5, #T_ab127_row13_col8, #T_ab127_row14_col5, #T_ab127_row15_col5, #T_ab127_row15_col8 {
#   background-color: #1515fe;
#   color: #f1f1f1;
# }
# #T_ab127_row8_col4, #T_ab127_row16_col5 {
#   background-color: #0707ff;
#   color: #f1f1f1;
# }
# #T_ab127_row8_col5, #T_ab127_row16_col8 {
#   background-color: #0e0efe;
#   color: #f1f1f1;
# }
# #T_ab127_row8_col9 {
#   background-color: #0d0dfe;
#   color: #f1f1f1;
# }
# #T_ab127_row9_col0, #T_ab127_row11_col0 {
#   background-color: #5c5cfa;
#   color: #f1f1f1;
# }
# #T_ab127_row9_col1, #T_ab127_row9_col5, #T_ab127_row11_col1, #T_ab127_row11_col5 {
#   background-color: #4040fc;
#   color: #f1f1f1;
# }
# #T_ab127_row9_col3, #T_ab127_row9_col6, #T_ab127_row11_col3, #T_ab127_row11_col6 {
#   background-color: #dedff4;
#   color: #000000;
# }
# #T_ab127_row9_col4, #T_ab127_row11_col4 {
#   background-color: #1b1bfe;
#   color: #f1f1f1;
# }
# #T_ab127_row9_col7, #T_ab127_row11_col7 {
#   background-color: #d5d5f4;
#   color: #000000;
# }
# #T_ab127_row9_col8, #T_ab127_row11_col8, #T_ab127_row12_col10 {
#   background-color: #0808ff;
#   color: #f1f1f1;
# }
# #T_ab127_row9_col9, #T_ab127_row11_col9, #T_ab127_row18_col8 {
#   background-color: #5353fb;
#   color: #f1f1f1;
# }
# #T_ab127_row10_col0 {
#   background-color: #1919fe;
#   color: #f1f1f1;
# }
# #T_ab127_row10_col2 {
#   background-color: #e0e0f4;
#   color: #000000;
# }
# #T_ab127_row10_col4 {
#   background-color: #0606ff;
#   color: #f1f1f1;
# }
# #T_ab127_row10_col5, #T_ab127_row12_col9, #T_ab127_row18_col5 {
#   background-color: #1818fe;
#   color: #f1f1f1;
# }
# #T_ab127_row10_col7 {
#   background-color: #8787f8;
#   color: #f1f1f1;
# }
# #T_ab127_row10_col8, #T_ab127_row14_col10 {
#   background-color: #0c0cfe;
#   color: #f1f1f1;
# }
# #T_ab127_row10_col9, #T_ab127_row13_col10, #T_ab127_row15_col10 {
#   background-color: #1f1ffd;
#   color: #f1f1f1;
# }
# #T_ab127_row12_col1, #T_ab127_row12_col4, #T_ab127_row16_col0 {
#   background-color: #0101ff;
#   color: #f1f1f1;
# }
# #T_ab127_row12_col7 {
#   background-color: #1616fe;
#   color: #f1f1f1;
# }
# #T_ab127_row13_col7, #T_ab127_row15_col7 {
#   background-color: #9292f8;
#   color: #f1f1f1;
# }
# #T_ab127_row13_col9, #T_ab127_row15_col9 {
#   background-color: #7d7df9;
#   color: #f1f1f1;
# }
# #T_ab127_row14_col1 {
#   background-color: #0202ff;
#   color: #f1f1f1;
# }
# #T_ab127_row14_col7 {
#   background-color: #4343fc;
#   color: #f1f1f1;
# }
# #T_ab127_row16_col4 {
#   background-color: #0b0bfe;
#   color: #f1f1f1;
# }
# #T_ab127_row16_col7 {
#   background-color: #0a0afe;
#   color: #f1f1f1;
# }
# #T_ab127_row16_col10 {
#   background-color: #1111fe;
#   color: #f1f1f1;
# }
# #T_ab127_row17_col7, #T_ab127_row19_col7 {
#   background-color: #b0b0f6;
#   color: #000000;
# }
# #T_ab127_row17_col9, #T_ab127_row19_col9 {
#   background-color: #9090f8;
#   color: #f1f1f1;
# }
# #T_ab127_row18_col7 {
#   background-color: #7373f9;
#   color: #f1f1f1;
# }
# #T_ab127_row18_col10 {
#   background-color: #1d1dfe;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ab127">
#   <caption>Metrics for Full Train/Test Datasets</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>

# %%
# load X_train_reduced and X_test_reduced
X_train_reduced_conservative = pd.read_csv(Path("./data/X_train_reduced_conservative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
X_test_reduced_conservative = pd.read_csv(Path("./data/X_test_reduced_conservative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

X_train_reduced_balanced = pd.read_csv(Path("./data/X_train_reduced_balanced.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
X_test_reduced_balanced = pd.read_csv(Path("./data/X_test_reduced_balanced.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

X_train_reduced_growth = pd.read_csv(Path("./data/X_train_reduced_growth.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
X_test_reduced_growth = pd.read_csv(Path("./data/X_test_reduced_growth.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

X_train_reduced_aggressive = pd.read_csv(Path("./data/X_train_reduced_aggressive.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
X_test_reduced_aggressive = pd.read_csv(Path("./data/X_test_reduced_aggressive.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

X_train_reduced_alternative = pd.read_csv(Path("./data/X_train_reduced_alternative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
X_test_reduced_alternative = pd.read_csv(Path("./data/X_test_reduced_alternative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)



#load y_train and y_test
y_train_conservative = pd.read_csv(Path("./data/y_train_conservative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
y_test_conservative = pd.read_csv(Path("./data/y_test_conservative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

y_train_balanced = pd.read_csv(Path("./data/y_train_balanced.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
y_test_balanced = pd.read_csv(Path("./data/y_test_balanced.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

y_train_growth = pd.read_csv(Path("./data/y_train_growth.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
y_test_growth = pd.read_csv(Path("./data/y_test_growth.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

y_train_aggressive = pd.read_csv(Path("./data/y_train_aggressive.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
y_test_aggressive = pd.read_csv(Path("./data/y_test_aggressive.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

y_train_alternative = pd.read_csv(Path("./data/y_train_alternative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)
y_test_alternative = pd.read_csv(Path("./data/y_test_alternative.csv"), index_col="Unnamed: 0", parse_dates=True, infer_datetime_format=True)

datafiles = {'conservative': [X_train_reduced_conservative,
                              X_test_reduced_conservative, 
                              y_train_conservative, 
                              y_test_conservative],
            'balanced': [X_train_reduced_balanced,
                              X_test_reduced_balanced, 
                              y_train_balanced, 
                              y_test_balanced],
            'growth': [X_train_reduced_growth,
                              X_test_reduced_growth, 
                              y_train_growth, 
                              y_test_growth],
            'aggressive': [X_train_reduced_aggressive,
                              X_test_reduced_aggressive, 
                              y_train_aggressive, 
                              y_test_aggressive],
            'alternative': [X_train_reduced_alternative,
                              X_test_reduced_alternative, 
                              y_train_alternative, 
                              y_test_alternative]}

portfolios = ['conservative', 'balanced', 'growth', 'aggressive','alternative']

df_reduced_results = pd.DataFrame()
for portfolio in portfolios:
    X_train = datafiles[portfolio][0]
    X_test = datafiles[portfolio][1]
    y_train = datafiles[portfolio][2]
    y_test = datafiles[portfolio][3]
    i=1
    df_results = pd.DataFrame()
    for model in models:
        pipeline = Pipeline([('scaler', scaler), ('model', model)])
        pipeline.fit(X_train, y_train)
        preds = pipeline.predict(X_test)
        report = classification_report(y_test, preds, output_dict=True)
        df = pd.DataFrame.from_dict(report['weighted avg'], orient='index', columns=[f'model{i}'])
        df.loc['accuracy',f'model{i}'] = report['accuracy']
        df_results = pd.concat([df_results, df], axis=1)
        df_results.drop('support', inplace=True)
        i += 1
    df_results['type'] = portfolio
    df_reduced_results = pd.concat([df_reduced_results, df_results])
    
df_reduced_results.set_index('type', append=True, inplace=True)
df_reduced_results = df_reduced_results.reorder_levels(['type', 0])

# %%
df_reduced_results['type'] = 'Linear Regression - Reduced'
df_full_results['type'] = 'Linear Regression - Full'


df_reduced_results.set_index('type', append=True,inplace=True)
df_full_results.set_index('type', append=True,inplace=True)

df_reduced_results = df_reduced_results.unstack(level=2)

df_reduced_results = df_reduced_results.reorder_levels([1,0], axis=1)


df_full_results = df_full_results.unstack(level=2)

df_full_results = df_full_results.reorder_levels([1,0], axis=1)

df_rf_results = pd.concat([df_reduced_results, df_full_results], axis=1)

cm = sns.light_palette("blue", as_cmap=True)
pd.set_option('display.max_columns', None)



df_rf_results.style.background_gradient(cmap=cm, axis=1).set_caption("Metrics for Reduced Train/Test Datasets")
# Out:
# <style type="text/css">
# #T_feba8_row0_col0, #T_feba8_row0_col1, #T_feba8_row0_col7, #T_feba8_row3_col0, #T_feba8_row3_col1, #T_feba8_row3_col7 {
#   background-color: #9d9df7;
#   color: #f1f1f1;
# }
# #T_feba8_row0_col2, #T_feba8_row0_col3, #T_feba8_row0_col6, #T_feba8_row0_col13, #T_feba8_row0_col14, #T_feba8_row0_col17, #T_feba8_row1_col2, #T_feba8_row1_col3, #T_feba8_row1_col6, #T_feba8_row1_col13, #T_feba8_row1_col14, #T_feba8_row1_col17, #T_feba8_row2_col2, #T_feba8_row2_col3, #T_feba8_row2_col6, #T_feba8_row2_col13, #T_feba8_row2_col14, #T_feba8_row2_col17, #T_feba8_row3_col2, #T_feba8_row3_col3, #T_feba8_row3_col6, #T_feba8_row3_col13, #T_feba8_row3_col14, #T_feba8_row3_col17, #T_feba8_row4_col10, #T_feba8_row5_col2, #T_feba8_row5_col3, #T_feba8_row5_col6, #T_feba8_row5_col13, #T_feba8_row5_col14, #T_feba8_row5_col17, #T_feba8_row6_col2, #T_feba8_row6_col3, #T_feba8_row6_col6, #T_feba8_row6_col13, #T_feba8_row6_col14, #T_feba8_row6_col17, #T_feba8_row7_col10, #T_feba8_row8_col2, #T_feba8_row8_col3, #T_feba8_row8_col6, #T_feba8_row8_col7, #T_feba8_row8_col13, #T_feba8_row8_col14, #T_feba8_row8_col17, #T_feba8_row9_col2, #T_feba8_row9_col3, #T_feba8_row9_col6, #T_feba8_row9_col7, #T_feba8_row9_col13, #T_feba8_row9_col14, #T_feba8_row9_col17, #T_feba8_row10_col2, #T_feba8_row10_col3, #T_feba8_row10_col6, #T_feba8_row10_col7, #T_feba8_row10_col13, #T_feba8_row10_col14, #T_feba8_row10_col17, #T_feba8_row11_col2, #T_feba8_row11_col3, #T_feba8_row11_col6, #T_feba8_row11_col7, #T_feba8_row11_col13, #T_feba8_row11_col14, #T_feba8_row11_col17, #T_feba8_row12_col12, #T_feba8_row13_col2, #T_feba8_row13_col3, #T_feba8_row13_col6, #T_feba8_row13_col7, #T_feba8_row13_col13, #T_feba8_row13_col14, #T_feba8_row13_col17, #T_feba8_row14_col2, #T_feba8_row14_col3, #T_feba8_row14_col6, #T_feba8_row14_col7, #T_feba8_row14_col13, #T_feba8_row14_col14, #T_feba8_row14_col17, #T_feba8_row15_col12, #T_feba8_row16_col13, #T_feba8_row17_col2, #T_feba8_row17_col3, #T_feba8_row17_col6, #T_feba8_row17_col14, #T_feba8_row17_col17, #T_feba8_row18_col2, #T_feba8_row18_col3, #T_feba8_row18_col6, #T_feba8_row18_col14, #T_feba8_row18_col17, #T_feba8_row19_col13 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_feba8_row0_col4, #T_feba8_row3_col4 {
#   background-color: #6969fa;
#   color: #f1f1f1;
# }
# #T_feba8_row0_col5, #T_feba8_row0_col18, #T_feba8_row3_col5, #T_feba8_row3_col18 {
#   background-color: #9292f8;
#   color: #f1f1f1;
# }
# #T_feba8_row0_col8, #T_feba8_row0_col20, #T_feba8_row3_col8, #T_feba8_row3_col20 {
#   background-color: #7d7df9;
#   color: #f1f1f1;
# }
# #T_feba8_row0_col9, #T_feba8_row0_col10, #T_feba8_row3_col9, #T_feba8_row3_col10 {
#   background-color: #bdbdf5;
#   color: #000000;
# }
# #T_feba8_row0_col11, #T_feba8_row1_col0, #T_feba8_row3_col11, #T_feba8_row5_col4, #T_feba8_row17_col8, #T_feba8_row18_col18 {
#   background-color: #2929fd;
#   color: #f1f1f1;
# }
# #T_feba8_row0_col12, #T_feba8_row0_col15, #T_feba8_row1_col15, #T_feba8_row2_col19, #T_feba8_row3_col12, #T_feba8_row3_col15, #T_feba8_row4_col12, #T_feba8_row5_col11, #T_feba8_row6_col8, #T_feba8_row7_col12, #T_feba8_row8_col11, #T_feba8_row8_col12, #T_feba8_row9_col10, #T_feba8_row10_col18, #T_feba8_row11_col11, #T_feba8_row11_col12, #T_feba8_row12_col8, #T_feba8_row13_col1, #T_feba8_row14_col9, #T_feba8_row15_col8, #T_feba8_row16_col21, #T_feba8_row17_col21, #T_feba8_row18_col19, #T_feba8_row18_col21, #T_feba8_row19_col21 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_feba8_row0_col16, #T_feba8_row0_col19, #T_feba8_row1_col16, #T_feba8_row3_col16, #T_feba8_row3_col19, #T_feba8_row6_col15, #T_feba8_row18_col11 {
#   background-color: #1515fe;
#   color: #f1f1f1;
# }
# #T_feba8_row0_col21, #T_feba8_row2_col0, #T_feba8_row2_col5, #T_feba8_row3_col21, #T_feba8_row17_col20 {
#   background-color: #1f1ffd;
#   color: #f1f1f1;
# }
# #T_feba8_row1_col1, #T_feba8_row8_col0, #T_feba8_row8_col10, #T_feba8_row11_col0, #T_feba8_row11_col10, #T_feba8_row12_col5, #T_feba8_row12_col11, #T_feba8_row13_col16, #T_feba8_row14_col16, #T_feba8_row15_col5, #T_feba8_row15_col11 {
#   background-color: #2b2bfd;
#   color: #f1f1f1;
# }
# #T_feba8_row1_col4, #T_feba8_row2_col8 {
#   background-color: #1a1afe;
#   color: #f1f1f1;
# }
# #T_feba8_row1_col5, #T_feba8_row6_col10, #T_feba8_row9_col21 {
#   background-color: #3131fd;
#   color: #f1f1f1;
# }
# #T_feba8_row1_col7, #T_feba8_row18_col7 {
#   background-color: #2d2dfd;
#   color: #f1f1f1;
# }
# #T_feba8_row1_col8, #T_feba8_row5_col7, #T_feba8_row5_col10 {
#   background-color: #3f3ffc;
#   color: #f1f1f1;
# }
# #T_feba8_row1_col9 {
#   background-color: #3d3dfc;
#   color: #f1f1f1;
# }
# #T_feba8_row1_col10, #T_feba8_row9_col0 {
#   background-color: #3333fc;
#   color: #f1f1f1;
# }
# #T_feba8_row1_col11, #T_feba8_row2_col11, #T_feba8_row5_col12, #T_feba8_row6_col12, #T_feba8_row14_col20 {
#   background-color: #0909ff;
#   color: #f1f1f1;
# }
# #T_feba8_row1_col12 {
#   background-color: #0202ff;
#   color: #f1f1f1;
# }
# #T_feba8_row1_col18, #T_feba8_row10_col9 {
#   background-color: #4343fc;
#   color: #f1f1f1;
# }
# #T_feba8_row1_col19, #T_feba8_row5_col20, #T_feba8_row6_col9, #T_feba8_row9_col8 {
#   background-color: #2222fd;
#   color: #f1f1f1;
# }
# #T_feba8_row1_col20 {
#   background-color: #2424fd;
#   color: #f1f1f1;
# }
# #T_feba8_row1_col21, #T_feba8_row13_col0, #T_feba8_row13_col4, #T_feba8_row14_col11, #T_feba8_row17_col19 {
#   background-color: #0c0cfe;
#   color: #f1f1f1;
# }
# #T_feba8_row2_col1, #T_feba8_row5_col1 {
#   background-color: #2121fd;
#   color: #f1f1f1;
# }
# #T_feba8_row2_col4, #T_feba8_row2_col18, #T_feba8_row8_col4, #T_feba8_row9_col5, #T_feba8_row11_col4, #T_feba8_row12_col0, #T_feba8_row12_col1, #T_feba8_row12_col4, #T_feba8_row15_col0, #T_feba8_row15_col1, #T_feba8_row15_col4, #T_feba8_row18_col5 {
#   background-color: #1616fe;
#   color: #f1f1f1;
# }
# #T_feba8_row2_col7, #T_feba8_row9_col16, #T_feba8_row18_col9 {
#   background-color: #1e1efd;
#   color: #f1f1f1;
# }
# #T_feba8_row2_col9 {
#   background-color: #2323fd;
#   color: #f1f1f1;
# }
# #T_feba8_row2_col10 {
#   background-color: #2727fd;
#   color: #f1f1f1;
# }
# #T_feba8_row2_col12, #T_feba8_row2_col15, #T_feba8_row6_col7 {
#   background-color: #0101ff;
#   color: #f1f1f1;
# }
# #T_feba8_row2_col16 {
#   background-color: #0303ff;
#   color: #f1f1f1;
# }
# #T_feba8_row2_col20, #T_feba8_row5_col16, #T_feba8_row6_col19, #T_feba8_row17_col16 {
#   background-color: #1818fe;
#   color: #f1f1f1;
# }
# #T_feba8_row2_col21, #T_feba8_row16_col19, #T_feba8_row19_col19 {
#   background-color: #0808ff;
#   color: #f1f1f1;
# }
# #T_feba8_row4_col0, #T_feba8_row4_col5, #T_feba8_row4_col20, #T_feba8_row7_col0, #T_feba8_row7_col5, #T_feba8_row7_col20 {
#   background-color: #7f7ff9;
#   color: #f1f1f1;
# }
# #T_feba8_row4_col1, #T_feba8_row7_col1 {
#   background-color: #8d8df8;
#   color: #f1f1f1;
# }
# #T_feba8_row4_col2, #T_feba8_row4_col3, #T_feba8_row4_col6, #T_feba8_row4_col13, #T_feba8_row4_col14, #T_feba8_row4_col17, #T_feba8_row7_col2, #T_feba8_row7_col3, #T_feba8_row7_col6, #T_feba8_row7_col13, #T_feba8_row7_col14, #T_feba8_row7_col17 {
#   background-color: #d4d4f4;
#   color: #000000;
# }
# #T_feba8_row4_col4, #T_feba8_row7_col4 {
#   background-color: #c6c6f5;
#   color: #000000;
# }
# #T_feba8_row4_col7, #T_feba8_row5_col9, #T_feba8_row7_col7, #T_feba8_row9_col15, #T_feba8_row13_col12 {
#   background-color: #3939fc;
#   color: #f1f1f1;
# }
# #T_feba8_row4_col8, #T_feba8_row6_col0, #T_feba8_row7_col8 {
#   background-color: #1c1cfe;
#   color: #f1f1f1;
# }
# #T_feba8_row4_col9, #T_feba8_row7_col9 {
#   background-color: #b8b8f6;
#   color: #000000;
# }
# #T_feba8_row4_col11, #T_feba8_row7_col11, #T_feba8_row9_col4, #T_feba8_row18_col4, #T_feba8_row18_col16 {
#   background-color: #0e0efe;
#   color: #f1f1f1;
# }
# #T_feba8_row4_col15, #T_feba8_row7_col15 {
#   background-color: #4747fb;
#   color: #f1f1f1;
# }
# #T_feba8_row4_col16, #T_feba8_row7_col16, #T_feba8_row14_col21 {
#   background-color: #2a2afd;
#   color: #f1f1f1;
# }
# #T_feba8_row4_col18, #T_feba8_row7_col18 {
#   background-color: #9c9cf7;
#   color: #f1f1f1;
# }
# #T_feba8_row4_col19, #T_feba8_row7_col19 {
#   background-color: #5555fb;
#   color: #f1f1f1;
# }
# #T_feba8_row4_col21, #T_feba8_row7_col21 {

# %%
best = df_rf_results['Linear Regression - Full'][['model11']]

best.reset_index(inplace=True)

best.to_csv(Path("./model_metrics/random_forest.csv"), index=False)
