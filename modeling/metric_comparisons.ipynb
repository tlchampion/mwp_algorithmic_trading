# %%
# import modules
import panel as pn
pn.extension('tabulator')
import pandas as pd
import numpy as np
from panel.template import FastListTemplate
from pathlib import Path
from yahoo_fin.stock_info import get_data
import datetime
from matplotlib.figure import Figure
from matplotlib import cm
# %matplotlib inline
import hvplot.pandas
import holoviews as hv
from holoviews import opts


import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# import modules that help build tabs
import modules.helpers as helpers
import modules.HistoricalData as hst
import modules.MCTab as MCTab
import modules.intro as intro
import modules.profile as prf
import modules.algorithmic_functions as af


import pandas_ta as ta
import yfinance as yf

from sklearn.linear_model import LogisticRegression
from pandas.tseries.offsets import DateOffset
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
import seaborn as sns

from joblib import dump, load
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
bagging = pd.read_csv(Path("./model_metrics/bagging_classifier.csv"), infer_datetime_format=True, parse_dates=True, index_col=['type', 'level_1'])
centroid = pd.read_csv(Path("./model_metrics/centroid.csv"), infer_datetime_format=True, parse_dates=True, index_col=['type', 'level_1'])
gaussian = pd.read_csv(Path("./model_metrics/gaussian.csv"), infer_datetime_format=True, parse_dates=True, index_col=['type', 'level_1'])
logistic_regression = pd.read_csv(Path("./model_metrics/logistic_regression.csv"), infer_datetime_format=True, parse_dates=True, index_col=['type', 'level_1'])
random_forest = pd.read_csv(Path("./model_metrics/random_forest.csv"), infer_datetime_format=True, parse_dates=True, index_col=['type', 'level_1'])
svm = pd.read_csv(Path("./model_metrics/svm.csv"), infer_datetime_format=True, parse_dates=True, index_col=['type', 'level_1'])

# %%
bagging.columns=['bagging']
centroid.columns=['centroid']
gaussian.columns=['gaussian']
logistic_regression.columns=['lr']
random_forest.columns=['rf']
svm.columns=['svm']

# %%
metrics = pd.concat([bagging,centroid, gaussian, logistic_regression, random_forest, svm], axis=1)

# %%
metrics
# Out:
#                          bagging  centroid  gaussian        lr        rf  \
# type         level_1
# aggressive   accuracy   0.524324  0.510811  0.524324  0.510811  0.543243
#              f1-score   0.522984  0.345414  0.485003  0.490002  0.538153
#              precision  0.523608  0.260928  0.526304  0.518575  0.542908
#              recall     0.524324  0.510811  0.524324  0.510811  0.543243
# alternative  accuracy   0.554054  0.510811  0.527027  0.483784  0.510811
#              f1-score   0.552374  0.345414  0.491963  0.368238  0.502110
#              precision  0.553627  0.260928  0.529357  0.473243  0.508732
#              recall     0.554054  0.510811  0.527027  0.483784  0.510811
# balanced     accuracy   0.521327  0.535545  0.464455  0.492891  0.497630
#              f1-score   0.477480  0.426157  0.336087  0.415042  0.472319
#              precision  0.548410  0.583481  0.400541  0.511846  0.506773
#              recall     0.521327  0.535545  0.464455  0.492891  0.497630
# conservative accuracy   0.521327  0.478673  0.459716  0.478673  0.469194
#              f1-score   0.515674  0.315158  0.321335  0.436279  0.468693
#              precision  0.530240  0.751749  0.395899  0.491147  0.472344
#              recall     0.521327  0.478673  0.459716  0.478673  0.469194
# growth       accuracy   0.527027  0.510811  0.532432  0.494595  0.554054
#              f1-score   0.527079  0.345414  0.500771  0.446955  0.548549
#              precision  0.527323  0.260928  0.535969  0.501729  0.554300
#              recall     0.527027  0.510811  0.532432  0.494595  0.554054
#
#                              svm
# type         level_1
# aggressive   accuracy   0.537838
#              f1-score   0.532711
#              precision  0.542408
#              recall     0.537838
# alternative  accuracy   0.478378
#              f1-score   0.418719
#              precision  0.474866
#              recall     0.478378
# balanced     accuracy   0.516588
#              f1-score   0.492231
#              precision  0.530645
#              recall     0.516588
# conservative accuracy   0.516588
#              f1-score   0.515719
#              precision  0.520833
#              recall     0.516588
# growth       accuracy   0.527027
#              f1-score   0.492387
#              precision  0.545837
#              recall     0.527027

# %%
cm = sns.light_palette("blue", as_cmap=True)



metrics.style.background_gradient(cmap=cm, axis=1).set_caption("Metrics for Reduced Train/Test Datasets")
# Out:
# <style type="text/css">
# #T_2ee54_row0_col0, #T_2ee54_row0_col2, #T_2ee54_row3_col0, #T_2ee54_row3_col2 {
#   background-color: #8c8cf8;
#   color: #f1f1f1;
# }
# #T_2ee54_row0_col1, #T_2ee54_row0_col3, #T_2ee54_row1_col1, #T_2ee54_row2_col1, #T_2ee54_row3_col1, #T_2ee54_row3_col3, #T_2ee54_row4_col5, #T_2ee54_row5_col1, #T_2ee54_row6_col1, #T_2ee54_row7_col5, #T_2ee54_row8_col2, #T_2ee54_row9_col2, #T_2ee54_row10_col2, #T_2ee54_row11_col2, #T_2ee54_row12_col2, #T_2ee54_row13_col1, #T_2ee54_row14_col2, #T_2ee54_row15_col2, #T_2ee54_row16_col3, #T_2ee54_row17_col1, #T_2ee54_row18_col1, #T_2ee54_row19_col3 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_2ee54_row0_col4, #T_2ee54_row1_col4, #T_2ee54_row2_col4, #T_2ee54_row2_col5, #T_2ee54_row3_col4, #T_2ee54_row4_col0, #T_2ee54_row5_col0, #T_2ee54_row6_col0, #T_2ee54_row7_col0, #T_2ee54_row8_col1, #T_2ee54_row9_col5, #T_2ee54_row10_col1, #T_2ee54_row11_col1, #T_2ee54_row12_col0, #T_2ee54_row13_col0, #T_2ee54_row13_col5, #T_2ee54_row14_col1, #T_2ee54_row15_col0, #T_2ee54_row16_col4, #T_2ee54_row17_col4, #T_2ee54_row18_col4, #T_2ee54_row19_col4 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_2ee54_row0_col5, #T_2ee54_row3_col5 {
#   background-color: #2828fd;
#   color: #f1f1f1;
# }
# #T_2ee54_row1_col0 {
#   background-color: #1313fe;
#   color: #f1f1f1;
# }
# #T_2ee54_row1_col2, #T_2ee54_row6_col3, #T_2ee54_row17_col5 {
#   background-color: #4242fc;
#   color: #f1f1f1;
# }
# #T_2ee54_row1_col3 {
#   background-color: #3b3bfc;
#   color: #f1f1f1;
# }
# #T_2ee54_row1_col5, #T_2ee54_row18_col5 {
#   background-color: #0707ff;
#   color: #f1f1f1;
# }
# #T_2ee54_row2_col0 {
#   background-color: #1010fe;
#   color: #f1f1f1;
# }
# #T_2ee54_row2_col2, #T_2ee54_row18_col2 {
#   background-color: #0e0efe;
#   color: #f1f1f1;
# }
# #T_2ee54_row2_col3 {
#   background-color: #1515fe;
#   color: #f1f1f1;
# }
# #T_2ee54_row4_col1, #T_2ee54_row4_col4, #T_2ee54_row7_col1, #T_2ee54_row7_col4 {
#   background-color: #8a8af8;
#   color: #f1f1f1;
# }
# #T_2ee54_row4_col2, #T_2ee54_row7_col2 {
#   background-color: #5656fb;
#   color: #f1f1f1;
# }
# #T_2ee54_row4_col3, #T_2ee54_row7_col3 {
#   background-color: #dfdff4;
#   color: #000000;
# }
# #T_2ee54_row5_col2 {
#   background-color: #4646fb;
#   color: #f1f1f1;
# }
# #T_2ee54_row5_col3 {
#   background-color: #d6d6f4;
#   color: #000000;
# }
# #T_2ee54_row5_col4 {
#   background-color: #3a3afc;
#   color: #f1f1f1;
# }
# #T_2ee54_row5_col5 {
#   background-color: #9c9cf7;
#   color: #f1f1f1;
# }
# #T_2ee54_row6_col2 {
#   background-color: #1414fe;
#   color: #f1f1f1;
# }
# #T_2ee54_row6_col4 {
#   background-color: #2525fd;
#   color: #f1f1f1;
# }
# #T_2ee54_row6_col5, #T_2ee54_row8_col5, #T_2ee54_row11_col5 {
#   background-color: #4040fc;
#   color: #f1f1f1;
# }
# #T_2ee54_row8_col0, #T_2ee54_row11_col0 {
#   background-color: #3030fd;
#   color: #f1f1f1;
# }
# #T_2ee54_row8_col3, #T_2ee54_row11_col3 {
#   background-color: #9090f8;
#   color: #f1f1f1;
# }
# #T_2ee54_row8_col4, #T_2ee54_row11_col4 {
#   background-color: #8080f8;
#   color: #f1f1f1;
# }
# #T_2ee54_row9_col0 {
#   background-color: #1717fe;
#   color: #f1f1f1;
# }
# #T_2ee54_row9_col1 {
#   background-color: #6666fa;
#   color: #f1f1f1;
# }
# #T_2ee54_row9_col3 {
#   background-color: #7777f9;
#   color: #f1f1f1;
# }
# #T_2ee54_row9_col4 {
#   background-color: #1e1efd;
#   color: #f1f1f1;
# }
# #T_2ee54_row10_col0 {
#   background-color: #2e2efd;
#   color: #f1f1f1;
# }
# #T_2ee54_row10_col3 {
#   background-color: #5e5efa;
#   color: #f1f1f1;
# }
# #T_2ee54_row10_col4 {
#   background-color: #6565fa;
#   color: #f1f1f1;
# }
# #T_2ee54_row10_col5 {
#   background-color: #4545fb;
#   color: #f1f1f1;
# }
# #T_2ee54_row12_col1, #T_2ee54_row12_col3, #T_2ee54_row15_col1, #T_2ee54_row15_col3 {
#   background-color: #a7a7f7;
#   color: #000000;
# }
# #T_2ee54_row12_col4, #T_2ee54_row15_col4 {
#   background-color: #ccccf5;
#   color: #000000;
# }
# #T_2ee54_row12_col5, #T_2ee54_row15_col5 {
#   background-color: #1212fe;
#   color: #f1f1f1;
# }
# #T_2ee54_row13_col2 {
#   background-color: #eaeaf3;
#   color: #000000;
# }
# #T_2ee54_row13_col3 {
#   background-color: #5f5ffa;
#   color: #f1f1f1;
# }
# #T_2ee54_row13_col4, #T_2ee54_row17_col2 {
#   background-color: #3939fc;
#   color: #f1f1f1;
# }
# #T_2ee54_row14_col0 {
#   background-color: #9696f7;
#   color: #f1f1f1;
# }
# #T_2ee54_row14_col3 {
#   background-color: #b0b0f6;
#   color: #000000;
# }
# #T_2ee54_row14_col4 {
#   background-color: #bebef5;
#   color: #000000;
# }
# #T_2ee54_row14_col5 {
#   background-color: #9d9df7;
#   color: #f1f1f1;
# }
# #T_2ee54_row16_col0, #T_2ee54_row16_col5, #T_2ee54_row19_col0, #T_2ee54_row19_col5 {
#   background-color: #6d6df9;
#   color: #f1f1f1;
# }
# #T_2ee54_row16_col1, #T_2ee54_row19_col1 {
#   background-color: #afaff6;
#   color: #000000;
# }
# #T_2ee54_row16_col2, #T_2ee54_row19_col2 {
#   background-color: #5858fb;
#   color: #f1f1f1;
# }
# #T_2ee54_row17_col0 {
#   background-color: #1919fe;
#   color: #f1f1f1;
# }
# #T_2ee54_row17_col3 {
#   background-color: #7979f9;
#   color: #f1f1f1;
# }
# #T_2ee54_row18_col0 {
#   background-color: #1616fe;
#   color: #f1f1f1;
# }
# #T_2ee54_row18_col3 {
#   background-color: #2a2afd;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2ee54">
#   <caption>Metrics for Reduced Train/Test Datasets</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ee54_level0_col0" class="col_heading level0 col0" >bagging</th>
#       <th id="T_2ee54_level0_col1" class="col_heading level0 col1" >centroid</th>
#       <th id="T_2ee54_level0_col2" class="col_heading level0 col2" >gaussian</th>
#       <th id="T_2ee54_level0_col3" class="col_heading level0 col3" >lr</th>
#       <th id="T_2ee54_level0_col4" class="col_heading level0 col4" >rf</th>
#       <th id="T_2ee54_level0_col5" class="col_heading level0 col5" >svm</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >type</th>
#       <th class="index_name level1" >level_1</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ee54_level0_row0" class="row_heading level0 row0" rowspan="4">aggressive</th>
#       <th id="T_2ee54_level1_row0" class="row_heading level1 row0" >accuracy</th>
#       <td id="T_2ee54_row0_col0" class="data row0 col0" >0.524324</td>
#       <td id="T_2ee54_row0_col1" class="data row0 col1" >0.510811</td>
#       <td id="T_2ee54_row0_col2" class="data row0 col2" >0.524324</td>
#       <td id="T_2ee54_row0_col3" class="data row0 col3" >0.510811</td>
#       <td id="T_2ee54_row0_col4" class="data row0 col4" >0.543243</td>
#       <td id="T_2ee54_row0_col5" class="data row0 col5" >0.537838</td>
#     </tr>
#     <tr>
#       <th id="T_2ee54_level1_row1" class="row_heading level1 row1" >f1-score</th>
#       <td id="T_2ee54_row1_col0" class="data row1 col0" >0.522984</td>
#       <td id="T_2ee54_row1_col1" class="data row1 col1" >0.345414</td>
#       <td id="T_2ee54_row1_col2" class="data row1 col2" >0.485003</td>
#       <td id="T_2ee54_row1_col3" class="data row1 col3" >0.490002</td>
#       <td id="T_2ee54_row1_col4" class="data row1 col4" >0.538153</td>
#       <td id="T_2ee54_row1_col5" class="data row1 col5" >0.532711</td>
#     </tr>
#     <tr>
#       <th id="T_2ee54_level1_row2" class="row_heading level1 row2" >precision</th>
#       <td id="T_2ee54_row2_col0" class="data row2 col0" >0.523608</td>
#       <td id="T_2ee54_row2_col1" class="data row2 col1" >0.260928</td>
#       <td id="T_2ee54_row2_col2" class="data row2 col2" >0.526304</td>
#       <td id="T_2ee54_row2_col3" class="data row2 col3" >0.518575</td>
#       <td id="T_2ee54_row2_col4" class="data row2 col4" >0.542908</td>
#       <td id="T_2ee54_row2_col5" class="data row2 col5" >0.542408</td>
#     </tr>
#     <tr>
#       <th id="T_2ee54_level1_row3" class="row_heading level1 row3" >recall</th>
#       <td id="T_2ee54_row3_col0" class="data row3 col0" >0.524324</td>
#       <td id="T_2ee54_row3_col1" class="data row3 col1" >0.510811</td>
#       <td id="T_2ee54_row3_col2" class="data row3 col2" >0.524324</td>
#       <td id="T_2ee54_r
