# %%
# import modules
import panel as pn
pn.extension('tabulator')
import pandas as pd
import numpy as np
from panel.template import FastListTemplate
from pathlib import Path
from yahoo_fin.stock_info import get_data
import datetime
from matplotlib.figure import Figure
from matplotlib import cm
# %matplotlib inline
import hvplot.pandas
import holoviews as hv
from holoviews import opts


import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# import modules that help build tabs
import modules.helpers as helpers
import modules.HistoricalData as hst
import modules.MCTab as MCTab
import modules.intro as intro
import modules.profile as prf
import modules.algorithmic_functions as af


import pandas_ta as ta
import yfinance as yf

from sklearn.linear_model import LogisticRegression
from pandas.tseries.offsets import DateOffset
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
import seaborn as sns

from joblib import dump, load
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %% [markdown]
# # Load all saved evaluation metrics from individual model train/testing. Combine into one dataframe for comparison and selection of best model per portfolio

# %%
bagging = pd.read_csv(Path("./model_metrics/bagging_classifier.csv"), infer_datetime_format=True, parse_dates=True, index_col=['type', 'level_1'])
adaboost = pd.read_csv(Path("./model_metrics/adaboost.csv"), infer_datetime_format=True, parse_dates=True, index_col=['type', 'level_1'])
gaussian = pd.read_csv(Path("./model_metrics/gaussian.csv"), infer_datetime_format=True, parse_dates=True, index_col=['type', 'level_1'])
logistic_regression = pd.read_csv(Path("./model_metrics/logistic_regression.csv"), infer_datetime_format=True, parse_dates=True, index_col=['type', 'level_1'])
random_forest = pd.read_csv(Path("./model_metrics/random_forest.csv"), infer_datetime_format=True, parse_dates=True, index_col=['type', 'level_1'])
svm = pd.read_csv(Path("./model_metrics/svm.csv"), infer_datetime_format=True, parse_dates=True, index_col=['type', 'level_1'])
nn = pd.read_csv(Path("./model_metrics/nn.csv"), infer_datetime_format=True, parse_dates=True, index_col=['type', 'level_1'])

# %%
adaboost.columns=['adaboost']
bagging.columns=['bagging']
# centroid.columns=['centroid']
gaussian.columns=['gaussian']
logistic_regression.columns=['lr']
random_forest.columns=['rf']
svm.columns=['svm']
nn.columns=['nn']

# %%
# metrics = pd.concat([bagging,centroid, gaussian, logistic_regression, random_forest, svm], axis=1)
metrics = pd.concat([adaboost, bagging, gaussian, logistic_regression, random_forest, svm, nn], axis=1)

# %%
display(metrics.style.highlight_max(color='lightblue', axis = 1).set_caption("Metrics Comparison for All Models"))




metrics.style.background_gradient(axis=1).set_caption("Metric Comparison Across Model Types")
# Out:
# <style type="text/css">
# #T_52c16_row0_col0, #T_52c16_row0_col2, #T_52c16_row0_col4, #T_52c16_row0_col5, #T_52c16_row1_col4, #T_52c16_row2_col0, #T_52c16_row2_col4, #T_52c16_row2_col5, #T_52c16_row3_col1, #T_52c16_row4_col0, #T_52c16_row4_col4, #T_52c16_row4_col5, #T_52c16_row5_col2, #T_52c16_row6_col0, #T_52c16_row6_col4, #T_52c16_row6_col5, #T_52c16_row7_col1, #T_52c16_row8_col0, #T_52c16_row8_col2, #T_52c16_row8_col4, #T_52c16_row8_col5, #T_52c16_row8_col6, #T_52c16_row9_col4 {
#   background-color: lightblue;
# }
# </style>
# <table id="T_52c16">
#   <caption>Metrics Comparison for All Models</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52c16_level0_col0" class="col_heading level0 col0" >adaboost</th>
#       <th id="T_52c16_level0_col1" class="col_heading level0 col1" >bagging</th>
#       <th id="T_52c16_level0_col2" class="col_heading level0 col2" >gaussian</th>
#       <th id="T_52c16_level0_col3" class="col_heading level0 col3" >lr</th>
#       <th id="T_52c16_level0_col4" class="col_heading level0 col4" >rf</th>
#       <th id="T_52c16_level0_col5" class="col_heading level0 col5" >svm</th>
#       <th id="T_52c16_level0_col6" class="col_heading level0 col6" >nn</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >type</th>
#       <th class="index_name level1" >level_1</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52c16_level0_row0" class="row_heading level0 row0" rowspan="2">aggressive</th>
#       <th id="T_52c16_level1_row0" class="row_heading level1 row0" >f1_score</th>
#       <td id="T_52c16_row0_col0" class="data row0 col0" >0.696104</td>
#       <td id="T_52c16_row0_col1" class="data row0 col1" >0.057554</td>
#       <td id="T_52c16_row0_col2" class="data row0 col2" >0.696104</td>
#       <td id="T_52c16_row0_col3" class="data row0 col3" >0.589569</td>
#       <td id="T_52c16_row0_col4" class="data row0 col4" >0.696104</td>
#       <td id="T_52c16_row0_col5" class="data row0 col5" >0.696104</td>
#       <td id="T_52c16_row0_col6" class="data row0 col6" >0.285714</td>
#     </tr>
#     <tr>
#       <th id="T_52c16_level1_row1" class="row_heading level1 row1" >roc_auc_score</th>
#       <td id="T_52c16_row1_col0" class="data row1 col0" >0.500000</td>
#       <td id="T_52c16_row1_col1" class="data row1 col1" >0.558107</td>
#       <td id="T_52c16_row1_col2" class="data row1 col2" >0.448909</td>
#       <td id="T_52c16_row1_col3" class="data row1 col3" >0.486276</td>
#       <td id="T_52c16_row1_col4" class="data row1 col4" >0.576158</td>
#       <td id="T_52c16_row1_col5" class="data row1 col5" >0.493175</td>
#       <td id="T_52c16_row1_col6" class="data row1 col6" >0.536995</td>
#     </tr>
#     <tr>
#       <th id="T_52c16_level0_row2" class="row_heading level0 row2" rowspan="2">alternative</th>
#       <th id="T_52c16_level1_row2" class="row_heading level1 row2" >f1_score</th>
#       <td id="T_52c16_row2_col0" class="data row2 col0" >0.696104</td>
#       <td id="T_52c16_row2_col1" class="data row2 col1" >0.043478</td>
#       <td id="T_52c16_row2_col2" class="data row2 col2" >0.640719</td>
#       <td id="T_52c16_row2_col3" class="data row2 col3" >0.636190</td>
#       <td id="T_52c16_row2_col4" class="data row2 col4" >0.696104</td>
#       <td id="T_52c16_row2_col5" class="data row2 col5" >0.696104</td>
#       <td id="T_52c16_row2_col6" class="data row2 col6" >0.677686</td>
#     </tr>
#     <tr>
#       <th id="T_52c16_level1_row3" class="row_heading level1 row3" >roc_auc_score</th>
#       <td id="T_52c16_row3_col0" class="data row3 col0" >0.500000</td>
#       <td id="T_52c16_row3_col1" class="data row3 col1" >0.552271</td>
#       <td id="T_52c16_row3_col2" class="data row3 col2" >0.495663</td>
#       <td id="T_52c16_row3_col3" class="data row3 col3" >0.471338</td>
#       <td id="T_52c16_row3_col4" class="data row3 col4" >0.545414</td>
#       <td id="T_52c16_row3_col5" class="data row3 col5" >0.540056</td>
#       <td id="T_52c16_row3_col6" class="data row3 col6" >0.524174</td>
#     </tr>
#     <tr>
#       <th id="T_52c16_level0_row4" class="row_heading level0 row4" rowspan="2">balanced</th>
#       <th id="T_52c16_level1_row4" class="row_heading level1 row4" >f1_score</th>
#       <td id="T_52c16_row4_col0" class="data row4 col0" >0.699229</td>
#       <td id="T_52c16_row4_col1" class="data row4 col1" >0.322917</td>
#       <td id="T_52c16_row4_col2" class="data row4 col2" >0.028571</td>
#       <td id="T_52c16_row4_col3" class="data row4 col3" >0.624561</td>
#       <td id="T_52c16_row4_col4" class="data row4 col4" >0.699229</td>
#       <td id="T_52c16_row4_col5" class="data row4 col5" >0.699229</td>
#       <td id="T_52c16_row4_col6" class="data row4 col6" >0.697674</td>
#     </tr>
#     <tr>
#       <th id="T_52c16_level1_row5" class="row_heading level1 row5" >roc_auc_score</th>
#       <td id="T_52c16_row5_col0" class="data row5 col0" >0.500000</td>
#       <td id="T_52c16_row5_col1" class="data row5 col1" >0.500346</td>
#       <td id="T_52c16_row5_col2" class="data row5 col2" >0.554990</td>
#       <td id="T_52c16_row5_col3" class="data row5 col3" >0.496852</td>
#       <td id="T_52c16_row5_col4" class="data row5 col4" >0.451860</td>
#       <td id="T_52c16_row5_col5" class="data row5 col5" >0.442245</td>
#       <td id="T_52c16_row5_col6" class="data row5 col6" >0.474548</td>
#     </tr>
#     <tr>
#       <th id="T_52c16_level0_row6" class="row_heading level0 row6" rowspan="2">conservative</th>
#       <th id="T_52c16_level1_row6" class="row_heading level1 row6" >f1_score</th>
#       <td id="T_52c16_row6_col0" class="data row6 col0" >0.661376</td>
#       <td id="T_52c16_row6_col1" class="data row6 col1" >0.404145</td>
#       <td id="T_52c16_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_52c16_row6_col3" class="data row6 col3" >0.583333</td>
#       <td id="T_52c16_row6_col4" class="data row6 col4" >0.661376</td>
#       <td id="T_52c16_row6_col5" class="data row6 col5" >0.661376</td>
#       <td id="T_52c16_row6_col6" class="data row6 col6" >0.442308</td>
#     </tr>
#     <tr>
#       <th id="T_52c16_level1_row7" class="row_heading level1 row7" >roc_auc_score</th>
#       <td id="T_52c16_row7_col0" class="data row7 col0" >0.500000</td>
#       <td id="T_52c16_row7_col1" class="data row7 col1" >0.566844</td>
#       <td id="T_52c16_row7_col2" class="data row7 col2" >0.549687</td>
#       <td id="T_52c16_row7_col3" class="data row7 col3" >0.458649</td>
#       <td id="T_52c16_row7_col4" class="data row7 col4" >0.506906</td>
#       <td id="T_52c16_row7_col5" class="data row7 col5" >0.490250</td>
#       <td id="T_52c16_row7_col6" class="data row7 col6" >0.534813</td>
#     </tr>
#     <tr>
#       <th id="T_52c16_level0_row8" class="row_heading level0 row8" rowspan="2">growth</th>
#       <th id="T_52c16_level1_row8" class="row_heading level1 row8" >f1_score</th>
#       <td id="T_52c16_row8_col0" class="data row8 col0" >0.699482</td>
#       <td id="T_52c16_row8_col1" class="data row8 col1" >0.056738</td>
#       <td id="T_52c16_row8_col2" class="data row8 col2" >0.699482</td>
#       <td id="T_52c16_row8_col3" class="data row8 col3" >0.606316</td>
#       <td id="T_52c16_row8_col4" class="data row8 col4" >0.699482</td>
#       <td id="T_52c16_row8_col5" class="data row8 col5" >0.699482</td>
#       <td id="T_52c16_row8_col6" class="data row8 col6" >0.699482</td>
#     </tr>
#     <tr>
#       <th id="T_52c16_level1_row9" class="row_heading level1 row9" >roc_auc_score</th>
#       <td id="T_52c16_row9_col0" class="data row9 col0" >0.500000</td>
#       <td id="T_52c16_row9_col1" class="data row9 col1" >0.507152</td>
#       <td id="T_52c16_row9_col2" class="data row9 col2" >0.449681</td>
#       <td id="T_52c16_row9_col3" class="data row9 col3" >0.489637</td>
#       <td id="T_52c16_row9_col4" class="data row9 co
# <style type="text/css">
# #T_a68bc_row0_col0, #T_a68bc_row0_col2, #T_a68bc_row0_col4, #T_a68bc_row0_col5, #T_a68bc_row1_col4, #T_a68bc_row2_col0, #T_a68bc_row2_col4, #T_a68bc_row2_col5, #T_a68bc_row3_col1, #T_a68bc_row4_col0, #T_a68bc_row4_col4, #T_a68bc_row4_col5, #T_a68bc_row4_col6, #T_a68bc_row5_col2, #T_a68bc_row6_col0, #T_a68bc_row6_col4, #T_a68bc_row6_col5, #T_a68bc_row7_col1, #T_a68bc_row8_col0, #T_a68bc_row8_col2, #T_a68bc_row8_col4, #T_a68bc_row8_col5, #T_a68bc_row8_col6, #T_a68bc_row9_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a68bc_row0_col1, #T_a68bc_row1_col2, #T_a68bc_row2_col1, #T_a68bc_row3_col3, #T_a68bc_row4_col2, #T_a68bc_row5_col5, #T_a68bc_row6_col2, #T_a68bc_row7_col3, #T_a68bc_row8_col1, #T_a68bc_row9_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a68bc_row0_col3 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_a68bc_row0_col6 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_a68bc_row1_col0 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_a68bc_row1_col1 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_a68bc_row1_col3 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_a68bc_row1_col5 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_a68bc_row1_col6 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_a68bc_row2_col2, #T_a68bc_row3_col4 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_a68bc_row2_col3 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_a68bc_row2_col6 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_a68bc_row3_col0 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_a68bc_row3_col2 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_a68bc_row3_col5 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_a68bc_row3_col6 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_a68bc_row4_col1, #T_a68bc_row9_col1 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_a68bc_row4_col3 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_a68bc_row5_col0, #T_a68bc_row5_col1 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_a68bc_row5_col3 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_a68bc_row5_col4 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_a68bc_row5_col6 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_a68bc_row6_col1 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_a68bc_row6_col3 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_a68bc_row6_col6 {
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# #T_a68bc_row7_col0 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_a68bc_row7_col2 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_a68bc_row7_col4 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_a68bc_row7_col5, #T_a68bc_row9_col5 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_a68bc_row7_col6 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_a68bc_row8_col3 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_a68bc_row9_col0 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_a68bc_row9_col3 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_a68bc_row9_col6 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a68bc">
#   <caption>Metric Comparison Across Model Types</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a68bc_level0_col0" class="col_heading level0 col0" >adaboost</th>
#       <th id="T_a68bc_level0_col1" class="col_heading level0 col1" >bagging</th>
#       <th id="T_a68bc_level0_col2" class="col_heading level0 col2" >gaussian</th>
#       <th id="T_a68bc_level0_col3" class="col_heading level0 col3" >lr</th>
#       <th id="T_a68bc_level0_col4" class="col_heading level0 col4" >rf</th>
#       <th id="T_a68bc_level0_col5" class="col_heading level0 col5" >svm</th>
#       <th id="T_a68bc_level0_col6" class="col_heading level0 col6" >nn</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >type</th>
#       <th class="index_name level1" >level_1</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a68bc_level0_row0" class="row_heading level0 row0" rowspan="2">aggressive</th>
#       <th id="T_a68bc_level1_row0" class="row_heading level1 row0" >f1_score</th>
#       <td id="T_a68bc_row0_col0" class="data row0 col0" >0.696104</td>
#       <td id="T_a68bc_row0_col1" class="data row0 col1" >0.057554</td>
#       <td id="T_a68bc_row0_col2" class="data row0 col2" >0.696104</td>
#       <td id="T_a68bc_row0_col3" class="data row0 col3" >0.589569</td>
#       <td id="T_a68bc_row0_col4" class="data row0 col4" >0.696104</td>
#       <td id="T_a68bc_row0_col5" class="data row0 col5" >0.696104</td>
#       <td id="T_a68bc_row0_col6" class="data row0 col6" >0.285714</td>
#     </tr>
#     <tr>
#       <th id="T_a68bc_level1_row1" class="row_heading level1 row1" >roc_auc_score</th>
#       <td id="T_a68bc_row1_col0" class="data row1 col0" >0.500000</td>
#       <td id="T_a68bc_row1_col1" class="data row1 col1" >0.558107</td>
#       <td id="T_a68bc_row1_col2" class="data row1 col2" >0.448909</td>
#       <td id="T_a68bc_row1_col3" class="data row1 col3" >0.486276</td>
#       <td id="T_a68bc_row1_col4" class="data row1 col4" >0.576158</td>
#       <td id="T_a68bc_row1_col5" class="data row1 col5" >0.493175</td>
#       <td id="T_a68bc_row1_col6" class="data row1 col6" >0.536995</td>
#     </tr>
#     <tr>
#       <th id="T_a68bc_level0_row2" class="row_heading level0 row2" rowspan="2">alternative</th>
#       <th id="T_a68bc_level1_row2" class="row_heading level1 row2" >f1_score</th>
#       <td id="T_a68bc_row2_col0" class="data row2 col0" >0.696104</td>
#       <td id="T_a68bc_row2_col1" class="data row2 col1" >0.043478</td>
#       <td id="T_a68bc_row2_col2" class="data row2 col2" >0.640719</td>
#       <td id="T_a68bc_row2_col3" class="data row2 col3" >0.636190</td>
#       <td id="T_a68bc_row2_col4" class="data row2 col4" >0.696104</td>
#       <td id="T_a68bc_row2_col5" class="data row2 col5" >0.696104</td>
#       <td id="T_a68bc_row2_col6" class="data row2 col6" >0.677686</td>
#     </tr>
#     <tr>
#       <th id="T_a68bc_level1_row3" class="row_heading level1 row3" >roc_auc_score</th>
#       <td id="T_a68bc_row3_col0" class="data row3 col0" >0.500000</td>
#       <td id="T_a68bc_row3_col1" class="data row3 col1" >0.552271</td>
#       <td id="T_a68bc_row3_col2" class="data row3 col2" >0.495663</td>
#       <td id="T_a68bc_row3_col3" class="data row3 col3" >0.471338</td>
#       <td id="T_a68bc_row3_col4" class="data row3 col4" >0.545414</td>
#       <td id="T_a68bc_row3_col5" class="data row3 col5" >0.540056</td>
#       <td id="T_a68bc_row3_col6" class="data row3 col6" >0.524174</td>
#     </tr>
#     <tr>
#       <th id="T_a68bc_level0_row4" class="row_heading level0 row4" rowspan="2">balanced</th>
#       <th id="T_a68bc_level1_row4" class="row_heading level1 row4" >f1_score</th>
#       <td id="T_a68bc_row4_col0" class="data row4 col0" >0.699229</td>
#       <td id="T_a68bc_row4_col1" class="data row4 col1" >0.322917</td>
#       <td id="T_a68bc_row4_col2" class="data row4 col2" >0.028571</td>
#       <td id="T_a68bc_row4_col3" class="data row4 col3" >0.624561</td>
#       <td id="T_a68bc_row4_col4" class="data row4 col4" >0.699229</td>
#       <td id="T_a68bc_row4_col5" class="data row4 col5" >0.699229</td>
#       <td id="T_a68bc_row4_col6" class="data row4 col6" >0.697674</td>
#     </tr>
#     <tr>
#       <th id="T_a68bc_level1_row5" class="row_heading level1 row5" >roc_auc_score</th>
#       <td id="T_a68bc_row5_col0" class="data row5 col0" >0.500000</td>
#       <td id="T_a68bc_row5_col1" class="data row5 col1" >0.500346</td>
#       <td id="T_a68bc_row5_col2" class="data row5 col2" >0.554990</td>
#       <td id="T_a68bc_row5_col3" class="data row5 col3" >0.496852</td>
#       <td id="T_a68bc_row5_col4"
